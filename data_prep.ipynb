# %%
import os
import pandas as pd

data_folder = "./data"
files = os.listdir(data_folder)
habitat_connectivity = pd.read_excel(os.path.join(data_folder, 'UK-BDI-2025-habitat-connectivity.xlsx'), sheet_name=None)
insects_wider_countryside = pd.read_excel(os.path.join(data_folder, 'UK-BDI-2025-insects-wider-countryside.xlsx'), sheet_name=None)
plants_wider_countryside = pd.read_excel(os.path.join(data_folder, 'UK-BDI-2025-plants-wider-countryside.xlsx'), sheet_name=None)
pollinating_insects = pd.read_excel(os.path.join(data_folder, 'UK-BDI-2025-pollinating-insects.xlsx'), sheet_name=None)

# %%
# Out:
#                     Table of contents   \
# 0  This worksheet contains one table.
# 1                     Worksheet number
# 2                                    1
# 3                                    2
# 4                                    3
# 5                                    4
# 6                                    5
# 7                                    6
# 8                                    7
# 9                                    8
#
#                                           Unnamed: 1  \
# 0                                                NaN
# 1                                    Worksheet title
# 2  Composite trends in functional connectivity in...
# 3  Summary of individual species trends in functi...
# 4  Functional connectivity in UK butterflies, 198...
# 5  Composite trends in functional connectivity in...
# 6  Summary of individual species trends in functi...
# 7  Functional connectivity in UK birds, 1985 to 2...
# 8  Mean connectivity values for various habitats ...
# 9  Mean connectivity values for various habitats ...
#
#                                           Unnamed: 2
# 0                                                NaN
# 1                                            Source
# 2  UK Butterfly Monitoring Scheme and University ...
# 3  UK Butterfly Monitoring Scheme and University ...
# 4  UK Butterfly Monitoring Scheme and University ...
# 5  British Trust for Ornithology and University o...
# 6  British Trust for Ornithology and University o...
# 7  British Trust for Ornithology and University o...
# 8  UK Centre for Ecology & Hydrology and Forest R...
# 9  UK Centre for Ecology & Hydrology and Forest R...
